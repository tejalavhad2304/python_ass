# %%
import numpy as np
arr = np.array([10,20,30,40,50])
arr = np.delete(arr,2)
print("resulting array:",arr)
# Out:
# resulting array: [10 20 40 50]

# %%
import numpy as np
arr1 = np.array([10,20,30])
arr2 = np.array([40,50,60])
result = np.concatenate((arr1,arr2))
print("Concatenated array is:",result)
# Out:
# Concatenated array is: [10 20 30 40 50 60]

# %%
import numpy as np 
arr = np.array([50,10,40,20,30])
print(np.sort(arr))
# Out:
# [10 20 30 40 50]

# %%
import numpy as np 
arr = np.array([10,0,20,0,30,0,40])
print(np.nonzero(arr))
# Out:
# (array([0, 2, 4, 6]),)

# %%
import numpy as np
arr = np.array([10,20,30,40,50])
print(np.searchsorted(arr,35))
# Out:
# 3

# %%
import numpy as np 
arr = np.array([10,20,20,30,10,40,50])
print(np.unique(arr))
# Out:
# [10 20 30 40 50]

# %%
import numpy as np 
arr = np.array([10,0,20,0,30,40,0])
print(np.count_nonzero(arr))
# Out:
# 4

# %%
import numpy as np
arr=np.array([10,20,30])
print(np.repeat(arr,3))
# Out:
# [10 10 10 20 20 20 30 30 30]

# %%
import numpy as np 
arr = np.array([85,90,75,88,92])
print(arr)
print(np.sum(arr))
print(np.mean(arr))
print(np.median(arr))
print(np.max(arr))
print(np.min(arr))
# Out:
# [85 90 75 88 92]
# 430
# 86.0
# 88.0
# 92
# 75

# %%
import numpy as np
arr = np.array([10,20,30,40])
print(arr)
print(arr.ndim)
print(arr.shape)
print(arr.size)
print(arr.dtype)
print(arr.itemsize)
print(arr.nbytes)
# Out:
# [10 20 30 40]
# 1
# (4,)
# 4
# int64
# 8
# 32

# %%
import numpy as np
arr1= np.array([10,20,30])
arr2 = np.array([40,50,60])
result = np.stack((arr1,arr2))
print("resulting array:",result)
# Out:
# resulting array: [[10 20 30]
#  [40 50 60]]

# %%
import numpy as np
arr=np.array([10,20,30,40])
copy_arr = arr.copy()
copy_arr[1]=100

print("Original array:",arr)
print("Copy array:",copy_arr)
# Out:
# Original array: [10 20 30 40]
# Copy array: [ 10 100  30  40]
